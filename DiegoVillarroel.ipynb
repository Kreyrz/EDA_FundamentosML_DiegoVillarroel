# %% [markdown]
# # Introduccion

# %% [markdown]
# La agrupacion de datos de **Online Retail** es un recurso de valor para el analisis de las transacciones en cuanto a comercio electronico se refiere, este fue publicado por el UCI **Machile Learning Repository**, este dataset tiene la informacion de de las compras realizadas de diciembre de 2010 a dicienmbre de 2011 en una tienda online de Reino Unido.
#
# Esta Empresa se dedica a la venta de regalos para ocasiones especiales y su clientela se centra en su mayoria por mayoristas.

# %%
import pandas as pd  # Biblioteca principal para el manejo de datos en DataFrames
import numpy as np  # Biblioteca para trabajar con arrays y operaciones matemáticas

import matplotlib.pyplot as plt  # Biblioteca para crear gráficos y visualizaciones
from matplotlib import style  # Estilo de gráficos de matplotlib
import seaborn as sns  # Biblioteca para mejorar la visualización con gráficos estadísticos

from scipy.stats import pearsonr  # Función para calcular la correlación de Pearson
from sklearn.linear_model import LinearRegression  # Modelo de regresión lineal de scikit-learn
from sklearn.model_selection import train_test_split  # Función para dividir los datos en conjunto de entrenamiento y prueba
from sklearn.metrics import r2_score  # Métrica para calcular el R^2 (coeficiente de determinación)
from sklearn.metrics import mean_squared_error  # Métrica para calcular el error cuadrático medio (MSE)

# Configuración de parámetros globales de visualización

plt.rcParams['image.cmap'] = "bwr"
#plt.rcParams['figure.dpi'] = "100"
plt.rcParams['savefig.bbox'] = "tight"


style.use('ggplot')

# Biblioteca para manejar advertencias
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive') #Codigo para la conexion de drive con el notebook
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
    name=fn
df = pd.read_csv(name, encoding='latin-1') # Aqui me ayudo la IA para la solucion del ingreso del archivo

df.head() #esto muestra las primeras 5 filas
# Out:
#      <input type="file" id="files-41ce16f7-8c19-421d-895b-b9e78ff1751a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-41ce16f7-8c19-421d-895b-b9e78ff1751a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.tail() #esto muestra las ultimas 5 filas
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/2011 12:50       0.85     12680.0  France
# 541905  12/9/2011 12:50       2.10     12680.0  France
# 541906  12/9/2011 12:50       4.15     12680.0  France
# 541907  12/9/2011 12:50       4.15     12680.0  France
# 541908  12/9/2011 12:50       4.95     12680.0  France

# %%
df.dtypes #esto sirve para ver los tipos de datos de las columnas
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
df['Quantity'].describe() #con esto mostraremos las estadisticas descriptivas de la columna a seleccionar
# Out:
# count    541909.000000
# mean          9.552250
# std         218.081158
# min      -80995.000000
# 25%           1.000000
# 50%           3.000000
# 75%          10.000000
# max       80995.000000
# Name: Quantity, dtype: float64

# %%
#En este caso no contamos con columnas irrelevantes pero por motivos practicos eliminaremos las estadisticas especiales.
df = df.drop(['InvoiceNo','Quantity', 'UnitPrice'], axis=1)

#Debemos eliminar valores duplicados, en este caso tenemos varios stats que se repiten pero los necesesitamos asi que eliminaremos los nombres duplicados.
df['Name'] = df['Name'].drop_duplicates().reset_index(drop=True)

#Eliminacion de los datos "null"
df = df.dropna()

df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-74eab2d5833c> in <cell line: 0>()
#       1 #En este caso no contamos con columnas irrelevantes pero por motivos practicos eliminaremos las estadisticas especiales.
# ----> 2 df = df.drop(['InvoiceNo','Quantity', 'UnitPrice'], axis=1)
#       3
#       4 #Debemos eliminar valores duplicados, en este caso tenemos varios stats que se repiten pero los necesesitamos asi que eliminaremos los nombres duplicados.
#       5 df['Name'] = df['Name'].drop_duplicates().reset_index(drop=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# ...
